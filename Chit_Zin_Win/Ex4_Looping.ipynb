# %% [markdown]
# <a href="https://colab.research.google.com/github/Ariel-Chole/MMDT_T-PY101_Batch03/blob/main/Chit_Zin_Win/Ex4_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
str_input = input("Enter a string: ")
length_str = len(str_input)
count = 0
while length_str != count:
  print(str_input[count])
  count += 1
# Out:
# Enter a string: Chit
# C
# h
# i
# t

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
weight = int(input("Enter the weight in kg: "))
while weight < 0 :
  print("Your entry is invalid!!")
  weight = int(input("Enter the weight in kg: "))

weight_in_lbs = weight * 2.20462
print(f"The weight {weight} kg is {weight_in_lbs} lbs.")
# Out:
# Enter the weight in kg: 100
# The weight 100 kg is 220.462 lbs.

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
test_score = int(input("Enter your test score: "))
total_score = 0
total_sub = 0
total_A = 0
while test_score >= 0:
  if test_score >= 90:
    total_A +=1

  total_score += test_score
  total_sub += 1
  print("If you are done, enter a negative number.")
  test_score = int(input("Enter your test score: "))

avg_score = total_score / total_sub
print("You get {} As.".format(total_A))
print(f"The average score is {avg_score}")
# Out:
# Enter your test score: 0
# If you are done, enter a negative number.
# Enter your test score: 90
# If you are done, enter a negative number.
# Enter your test score: 65
# If you are done, enter a negative number.
# Enter your test score: -1
# You get 1 As.
# The average score is 51.666666666666664

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
string = input("Enter a string: ")
letter = input("Enter a letter: ")
for i,c in enumerate(string):
  if letter == c:
    print(f"The index of the first occurrence of the letter is {i}.")
    break
else:
  print("The string does not contain the letter.")
# Out:
# Enter a string: My name is Chit Zin Win
# Enter a letter: i
# The index of the first occurrence of the letter is 8.

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
entry_list = [1,1,1,1,0,0,1]
for i,c in enumerate(entry_list):
  if c == 0:
    entry_list[i] = 1
    print(entry_list)
    break
else:
  print("There are no zero entries.")
# Out:
# [1, 1, 1, 1, 1, 0, 1]
